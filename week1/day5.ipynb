# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2025/09/15/ai-in-production-gen-ai-and-agentic-ai-on-aws-at-scale/',
#  'https://edwarddonner.com/2025/09/15/ai-in-production-gen-ai-and-agentic-ai-on-aws-at-scale/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page", "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page", "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2025/09/15/ai-in-production-gen-ai-and-agentic-ai-on-aws-at-scale/
# https://edwarddonner.com/2025/09/15/ai-in-production-gen-ai-and-agentic-ai-on-aws-at-scale/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  '/spaces',
#  '/models',
#  '/tencent/SRPO',
#  '/Alibaba-NLP/Tongyi-DeepResearch-30B-A3B',
#  '/openbmb/VoxCPM-0.5B',
#  '/ibm-granite/granite-docling-258M',
#  '/google/vaultgemma-1b',
#  '/models',
#  '/spaces/enzostvs/deepsite',
#  '/spaces/zerogpu-aoti/wan2-2-fp8da-aoti-faster',
#  '/spaces/Wan-AI/Wan2.2-Animate',
#  '/spaces/IndexTeam/IndexTTS-2-Demo',
#  '/spaces/abdul9999/NoWatermark',
#  '/spaces',
#  '/datasets/HuggingFaceFW/finepdfs',
#  '/datasets/fka/awesome-chatgpt-prompts',
#  '/datasets/InternRobotics/OmniWorld',
#  '/datasets/LucasFang/FLUX-Reason-6M',
#  '/datasets/HuggingFaceM4/FineVision',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/trl',
#  '/docs/transformers.js',
#  '/docs/smolagents',
#  '/docs/peft',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/changelog',
#  'https://endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'blog page', 'url': 'https://huggingface.co/blog'},
#   {'type': 'company page',
#    'url': 'https://www.linkedin.com/company/huggingface/'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'community discussion page', 'url': 'https://discuss.huggingface.co'}, {'type': 'status page', 'url': 'https://status.huggingface.co/'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# tencent/SRPO
# Updated
# 6 days ago
# •
# 7k
# •
# 862
# Alibaba-NLP/Tongyi-DeepResearch-30B-A3B
# Updated
# 4 days ago
# •
# 6.26k
# •
# 479
# openbmb/VoxCPM-0.5B
# Updated
# 2 days ago
# •
# 2.19k
# •
# 463
# ibm-granite/granite-docling-258M
# Updated
# 3 days ago
# •
# 16.4k
# •
# 428
# google/vaultgemma-1b
# Updated
# 9 days ago
# •
# 3.25k
# •
# 355
# Browse 1M+ models
# Spaces
# Running
# 14k
# 14k
# DeepSite v2
# 🐳
# Generate any application with DeepSeek
# Running
# on
# Zero
# MCP
# 1.18k
# 1.18k
# Wan2.2 14B Fast
# 🎥
# generate a video from an image with a text prompt
# Running
# 196
# 196
# Wan2.2 Animate
# 👁
# Wan2.2 Animate
# Running
# on
# Zero
# 241
# 241
# IndexTTS 2 Demo
# 🏢
# Generate expressive speech from text with emotion control
# Running
# 137
# 137
# NoWatermark
# ⚡
# Powerful Watermark Removal API
# Browse 400k+ applications
# Datasets
# HuggingFaceFW/finepdfs
# Updated
# 13 days ago
# •
# 74.6k
# •
# 545
# fka/awesome-chatgpt-prompts
# Updated
# Jan 6
# •
# 46.7k
# •
# 9.09k
# InternRobotics/OmniWorld
# Updated
# 12 minutes ago
# •
# 9.93k
# •
# 48
# LucasFang/FLUX-Reason-6M
# Updated
# 10 days ago
# •
# 34.5k
# •
# 72
# HuggingFaceM4/FineVision
# Updated
# 17 days ago
# •
# 246k
# •
# 336
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Team & Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Team
# non-profit
# •
# 792 models
# •
# 4.07k followers
# AI at Meta
# Enterprise
# company
# •
# 2.23k models
# •
# 7.93k followers
# Amazon
# Enterprise
# company
# •
# 20 models
# •
# 3.44k followers
# Google
# Enterprise
# company
# •
# 1.05k models
# •
# 30.1k followers
# Intel
# company
# •
# 239 models
# •
# 3.03k followers
# Microsoft
# Enterprise
# company
# •
# 424 models
# •
# 15.5k followers
# Grammarly
# Team
# company
# •
# 11 models
# •
# 180 followers
# Writer
# Enterprise
# company
# •
# 30 models
# •
# 348 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 150,042
# State-of-the-art AI models for PyTorch
# Diffusers
# 30,820
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,460
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,929
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 10,093
# Fast tokenizers optimized for research & production
# TRL
# 15,595
# Train transformers LMs with reinforcement learning
# Transformers.js
# 14,578
# State-of-the-art ML running directly in your browser
# smolagents
# 22,920
# Smol library to build great agents in Python
# PEFT
# 19,633
# Parameter-efficient finetuning for large language models
# Datasets
# 20,668
# Access & share datasets for any ML tasks
# Text Generation Inference
# 10,521
# Serve language models with TGI optimized toolkit
# Accelerate
# 9,149
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# about page
# Webpage Title:
# huggingface (Hugging Face)
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Hugging Face
# Enterprise
# company
# Verified
# https://huggingface.co
# huggingface
# huggingface
# Activity Feed
# Follow
# 60,132
# AI & ML interests
# The AI community building the future.
# Recent Activity
# jadechoghari
# updated
# a dataset
# about 8 hours ago
# huggingface/documentation-images
# julien-c
# updated
# a dataset
# 1 day ago
# huggingface/documentation-images
# giadap
# authored
# a paper
# 27 days ago
# INTIMA: A Benchmark for Human-AI Companionship Behavior
# View all activity
# Articles
# TimeScope: How Long Can Your Video Large Multimodal Model Go?
# Jul 23
# •
# 42
# Yay! Organizations can now publish blog Articles
# Jan 20
# •
# 51
# Team members
# 207
# +173
# +160
# +139
# +129
# +109
# Organization Card
# Community
# About org cards
# 👋 Hi!
# We are on a mission to democratize
# good
# machine learning, one commit at a time.
# If that sounds like something you should be doing, why don't you
# join us
# !
# For press enquiries, you can
# ✉️ contact our team here
# .
# Collections
# 1
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 130k
# •
# •
# 53
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 11.9M
# •
# •
# 758
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 1.18M
# •
# •
# 213
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# 0.1B
# •
# Updated
# Dec 19, 2023
# •
# 3.53M
# •
# •
# 827
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 130k
# •
# •
# 53
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 11.9M
# •
# •
# 758
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 1.18M
# •
# •
# 213
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# 0.1B
# •
# Updated
# Dec 19, 2023
# •
# 3.53M
# •
# •
# 827
# spaces
# 31
# Sort:
# 		Recently updated
# pinned
# Running
# 17
# Enterprise Hub
# 🔒
# Why you need it, how to get it
# huggingface
# Jun 27
# pinned
# Running
# on
# CPU Upgrade
# 21
# Hugging Face Fast
# 🏎
# Test your internet bandwidth
# huggingface
# Jun 12
# pinned
# Running
# 101
# Number Tokenization Blog
# 📈
# Explore how tokenization affects arithmetic in LLMs
# huggingface
# Dec 14, 2024
# Running
# on
# CPU Upgrade
# 215
# Inference Playground
# 🔋
# Set theme for Hugging Face Playground
# huggingface
# 5 days ago
# Running
# 503
# AI Deadlines
# ⚡
# Manage project deadlines with AI assistance
# huggingface
# 13 days ago
# Running
# on
# CPU Upgrade
# 22
# Openapi
# 🦀
# Hub API Documentation
# huggingface
# Jun 18
# View 31
# 							Spaces
# models
# 16
# Sort:
# 		Recently updated
# huggingface/time-series-transformer-tourism-monthly
# Time Series Forecasting
# •
# 0.0B
# •
# Updated
# May 24
# •
# 3.49k
# •
# 24
# huggingface/timesfm-tourism-monthly
# 0.0B
# •
# Updated
# Mar 31
# •
# 23
# •
# 3
# huggingface/CodeBERTa-language-id
# Text Classification
# •
# Updated
# Mar 29, 2024
# •
# 1.29k
# •
# •
# 64
# huggingface/falcon-40b-gptq
# Text Generation
# •
# 7B
# •
# Updated
# Jun 14, 2023
# •
# 25
# •
# 13
# huggingface/autoformer-tourism-monthly
# Updated
# May 24, 2023
# •
# 5.6k
# •
# 10
# huggingface/distilbert-base-uncased-finetuned-mnli
# Text Classification
# •
# 0.1B
# •
# Updated
# Mar 22, 2023
# •
# 173
# •
# 2
# huggingface/informer-tourism-monthly
# Updated
# Feb 24, 2023
# •
# 5.61k
# •
# 6
# huggingface/the-no-branch-repo
# Text-to-Image
# •
# Updated
# Feb 10, 2023
# •
# 13
# •
# 6
# huggingface/CodeBERTa-small-v1
# Fill-Mask
# •
# Updated
# Jun 27, 2022
# •
# 141k
# •
# •
# 84
# huggingface/test-model-repo
# Updated
# Nov 19, 2021
# •
# 2
# View 16
# 							models
# datasets
# 34
# Sort:
# 		Recently updated
# huggingface/documentation-images
# Viewer
# •
# Updated
# about 8 hours ago
# •
# 55
# •
# 2.58M
# •
# 82
# huggingface/diffusers-metadata
# Viewer
# •
# Updated
# 1 day ago
# •
# 78
# •
# 973
# •
# 8
# huggingface/transformers-metadata
# Viewer
# •
# Updated
# 2 days ago
# •
# 1.9k
# •
# 1.01k
# •
# 28
# huggingface/policy-docs
# Viewer
# •
# Updated
# 12 days ago
# •
# 28
# •
# 3.95k
# •
# 13
# huggingface/badges
# Viewer
# •
# Updated
# Jul 17
# •
# 1
# •
# 461k
# •
# 46
# huggingface/cats-image
# Viewer
# •
# Updated
# Jun 20
# •
# 1
# •
# 10.4k
# •
# 2
# huggingface/label-files
# Updated
# Jun 12
# •
# 1.92k
# •
# 19
# huggingface/electricity-production
# Viewer
# •
# Updated
# May 22
# •
# 397
# •
# 73
# •
# 1
# huggingface/gemini-results-new-cs-papers-2025-02-11-100-230-updated
# Viewer
# •
# Updated
# Feb 17
# •
# 130
# •
# 166
# huggingface/wiki_dpr
# Updated
# Feb 5
# •
# 415
# View 34
# 							datasets
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# blog page
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# LeRobot
# Inference Providers
# Scaleway on Hugging Face Inference Providers 🔥
# By
# sbrandeis
# September 19, 2025
# •
# 8
# Community Articles
# view all
# Introducing the Palmyra-mini family: Powerful, lightweight, and ready to reason!
# By
# Writer
# and 1 other
# •
# 10 days ago
# •
# 55
# How to Choose the Best Open Source LLM for Your Project in 2025
# By
# dvilasuero
# •
# 12 days ago
# •
# 70
# AtlasOCR: Building the First Open-Source Darija OCR Model with Vision Language Models
# By
# imomayiz
# and 4 others
# •
# 5 days ago
# •
# 11
# RexBERT: Encoders for a brave new world of E-Commerce
# By
# thebajajra
# and 1 other
# •
# about 17 hours ago
# •
# 10
# mem-agent: Persistent, Human Readable Memory Agent Trained with Online RL
# By
# driaforall
# and 1 other
# •
# 10 days ago
# •
# 17
# "Anemll-style" Root-Mean-Square (RMS) Normalization on the Apple Neural Engine: A Simple Hack
# By
# anemll
# •
# 5 days ago
# •
# 9
# PP-OCRv5 on Hugging Face: A Specialized Approach to OCR
# By
# baidu
# and 5 others
# •
# 11 days ago
# •
# 95
# How to Train an Antibody Developability Model
# By
# ginkgo-datapoints
# and 1 other
# •
# 4 days ago
# •
# 8
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 198
# Small Language Models (SLM): A Comprehensive Overview
# By
# jjokah
# •
# Feb 22
# •
# 70
# 🌎 What kind of environmental impacts are AI companies disclosing? (And can we compare them?) 🌎
# By
# sasha
# and 1 other
# •
# 4 days ago
# •
# 7
# Unleashing the Full Potential of ERNIE4.5 using FastDeploy
# By
# baidu
# and 3 others
# •
# 2 days ago
# •
# 7
# Fine-tune Llama 3.1 Ultra-Efficiently with Unsloth
# By
# mlabonne
# •
# Jul 29, 2024
# •
# 361
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 219
# Use AI on Your PC: Optimize and Deploy a Multimodal Agentic Pipeline on AI PC Powered by Intel
# By
# estellea
# and 2 others
# •
# 4 days ago
# •
# 5
# Finegrain Product Placement LoRA (experiment)
# By
# finegrain
# •
# 3 days ago
# •
# 5
# Decoding Strategies in Large Language Models
# By
# mlabonne
# •
# Oct 29, 2024
# •
# 89
# From GRPO to DAPO and GSPO: What, Why, and How
# By
# NormalUhr
# •
# Aug 9
# •
# 29
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 676
# Understanding Vector Quantization in VQ-VAE
# By
# ariG23498
# •
# Aug 28, 2024
# •
# 42
# Democratizing AI Safety with RiskRubric.ai
# By
# galmo-noma
# September 18, 2025
# •
# 14
# Public AI on Hugging Face Inference Providers 🔥
# By
# sbrandeis
# September 17, 2025
# •
# 10
# `LeRobotDataset`: Bringing large-scale datasets to lerobot
# By
# fracapuano
# September 16, 2025
# •
# 24
# Visible Watermarking with Gradio
# By
# meg
# September 15, 2025
# •
# 12
# Tricks from OpenAI gpt-oss YOU 🫵 can use with transformers
# By
# ariG23498
# September 11, 2025
# •
# 143
# Jupyter Agents: training LLMs to reason with notebooks
# By
# baptistecolle
# September 10, 2025
# •
# 34
# mmBERT: ModernBERT goes Multilingual
# By
# orionweller
# September 9, 2025
# •
# 92
# Welcome EmbeddingGemma, Google's new efficient embedding model
# By
# tomaarsen
# September 4, 2025
# •
# 219
# Make your ZeroGPU Spaces go brrr with PyTorch ahead-of-time compilation
# By
# cbensimon
# September 2, 2025
# •
# 58
# Generate Images with Claude and Hugging Face
# By
# evalstate
# August 19, 2025
# •
# 35
# From Zero to GPU: A Guide to Building and Scaling Production-Ready CUDA Kernels
# By
# drbh
# August 18, 2025
# •
# 69
# MCP for Research: How to Connect AI to Research Tools
# By
# dylanebert
# August 18, 2025
# •
# 54
# TextQuests: How Good are LLMs at Text-Based Video Games?
# By
# justinphan3110
# August 12, 2025
# guest
# •
# 34
# Introducing AI Sheets: a tool to work with datasets using open AI models!
# By
# dvilasuero
# August 8, 2025
# •
# 96
# Previous
# 1
# 2
# 3
# ...
# 45
# Next
# Community Articles
# Sort:
# 		Trending
# Introducing the Palmyra-mini family: Powerful, lightweight, and ready to reason!
# By
# Writer
# and 1 other
# •
# 10 days ago
# •
# 55
# How to Choose the Best Open Source LLM for Your Project in 2025
# By
# dvilasuero
# •
# 12 days ago
# •
# 70
# AtlasOCR: Building the First Open-Source Darija OCR Model with Vision Language Models
# By
# imomayiz
# and 4 others
# •
# 5 days ago
# •
# 11
# RexBERT: Encoders for a brave new world of E-Commerce
# By
# thebajajra
# and 1 other
# •
# about 17 hours ago
# •
# 10
# mem-agent: Persistent, Human Readable Memory Agent Trained with Online RL
# By
# driaforall
# and 1 other
# •
# 10 days ago
# •
# 17
# "Anemll-style" Root-Mean-Square (RMS) Normalization on the Apple Neural Engine: A Simple Hack
# By
# anemll
# •
# 5 days ago
# •
# 9
# PP-OCRv5 on Hugging Face: A Specialized Approach to OCR
# By
# baidu
# and 5 others
# •
# 11 days ago
# •
# 95
# How to Train an Antibody Developability Model
# By
# ginkgo-datapoints
# and 1 other
# •
# 4 days ago
# •
# 8
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 198
# Small Language Models (SLM): A Comprehensive Overview
# By
# jjokah
# •
# Feb 22
# •
# 70
# 🌎 What kind of environmental impacts are AI companies disclosing? (And can we compare them?) 🌎
# By
# sasha
# and 1 other
# •
# 4 days ago
# •
# 7
# Unleashing the Full Potential of ERNIE4.5 using FastDeploy
# By
# baidu
# and 3 others
# •
# 2 days ago
# •
# 7
# Fine-tune Llama 3.1 Ultra-Efficiently with Unsloth
# By
# mlabonne
# •
# Jul 29, 2024
# •
# 361
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 219
# Use AI on Your PC: Optimize and Deploy a Multimodal Agentic Pipeline on AI PC Powered by Intel
# By
# estellea
# and 2 others
# •
# 4 days ago
# •
# 5
# Finegrain Product Placement LoRA (experiment)
# By
# finegrain
# •
# 3 days ago
# •
# 5
# Decoding Strategies in Large Language Models
# By
# mlabonne
# •
# Oct 29, 2024
# •
# 89
# From GRPO to DAPO and GSPO: What, Why, and How
# By
# NormalUhr
# •
# Aug 9
# •
# 29
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 676
# Understanding Vector Quantization in VQ-VAE
# By
# ariG23498
# •
# Aug 28, 2024
# •
# 42
# View all
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# company page
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Top Content
# People
# Learning
# Jobs
# Games
# Get the app
# Sign in
# Join now
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# View all 623 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We’re on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# Terrence Rohan
# Seed Investor
# See all employees
# Updates
# Hugging Face
# reposted this
# Julien Chaumond
# CTO at Hugging Face
# 1d
# Report this post
# Your semi-regular reminder that Xet is a ground-breaking piece of tech 🔥
#
# Lets you store Large Files on the HF Hub faster, intelligently splits files into unique chunks, and accelerates both uploads and downloads.
#
# Total gamer-changer on the Hub and for the open AI field in general 🥳
# 252
# 8 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Vaibhav Srivastav
# whatever needs doing @ Hugging Face
# 4d
# Report this post
# BOOM! IBM just released an updated SmolDocling - tiny 258M param SoTA VLM - Apache 2.0 licensed! 🔥
#
# Capable of doing OCR, Visual QA, Translation and much more - try it out now:
# https://lnkd.in/gi8wUNsN
# 🤗
# …more
# 785
# 16 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Lysandre Debut
# COSO - Chief Open Source Officer at Hugging Face
# 2d
# Report this post
# Thinking back to the origins, BERT, ALBERT, DistilBERT all seemed so far apart
#
# Crazy to see them so tightly coupled in this timeline; we have truly come a long way since then. Encoder releases were so much more frequent than decoders back then.
#
# 409 architectures and counting!
# …more
# 212
# 6 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 69,723 followers
# 2d
# Edited
# Report this post
# BOOM!! Introducing Guided Image Edits with
# Google DeepMind
# 's Nano-Banana 😱
#
# A simple and intuitive UI to do guided and grounded image edits with your favorite AI 🔥⬇️⬇️
#
# With this app, we are also introducing
# Gradio
# 's NEW custom navbars.🔥
#
# Learn more about our gr.Navbar component here:
# https://lnkd.in/gUH-p2dX
# Guided nano-banana app on
# Hugging Face
# (FREE for next few hours😍):
# https://lnkd.in/gTv4ia8A
# The app is using the
# fal
# API to access nano-banana.💯
# …more
# 53
# 4 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Ben Burtenshaw
# Machine Learning @ 🤗 Hugging Face
# 3d
# Report this post
# I’m happy to share that I’ve obtained a new certification in Supervised Fine-tuning from the smol course on
# Hugging Face
# !
#
# Join the course and get your certificate :
# https://lnkd.in/e4XA7zQd
# This content isn’t available here
# Access this content and more in the LinkedIn app
# Download the app
# 134
# 8 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Lysandre Debut
# COSO - Chief Open Source Officer at Hugging Face
# 3d
# Report this post
# Packaging
# ggml
# 's
# llama.cpp
# efficiently is notoriously difficult; different feature flags enable wildly different performance depending on the hardware you're running on. There's a very active discussion on the topic over on
# llama.cpp
# 's GitHub (#15313)
#
# With Adrien we've taken a first stab at implementing a performance-optimized packaging solution, so that it's easily installable and takes advantage of the features your hardware provides.
#
# While still a WIP, it's working on Linux (cpu/cuda) now, we'll follow-up with Metal, and finally Windows.
#
# Check out the thread, it's a super interesting topic.
# 59
# 5 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Pablo Montalvo
# Machine Learning Engineer @ 🤗
# 4d
# Edited
# Report this post
# Meituan'𝘀 𝗟𝗼𝗻𝗴𝗖𝗮𝘁-𝗙𝗹𝗮𝘀𝗵 is a 560B MoE with two really neat ideas: zero-compute experts (some tokens skip compute) and a shortcut-connected MoE.
#
# It is now available on 𝘁𝗿𝗮𝗻𝘀𝗳𝗼𝗿𝗺𝗲𝗿𝘀! hub url: 𝗺𝗲𝗶𝘁𝘂𝗮𝗻-𝗹𝗼𝗻𝗴𝗰𝗮𝘁/𝗟𝗼𝗻𝗴𝗖𝗮𝘁-𝗙𝗹𝗮𝘀𝗵-𝗖𝗵𝗮𝘁
#
# Router activates ~27B params per token on average (18.6–31.3B), giving big-model quality at small-model cost, and long-context (128k).
#
# I love the simplicity of the zero-computation experts: if a token has low contextual importance, then the "expert" will be the identity function, if it is important, then an FFN block is chosen! Smart way to save compute and they have ablation studies to back it.
#
# Great work from Meituan! 🤗
# …more
# 104
# 3 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Peter W. J. Staar
# Principal Research Staff Member, Master Inventor, Manager of "AI for Knowledge" group in IBM Research Zurich; Chair of the technical steering committee of Docling in the Linux Foundation for AI and Data
# 4d
# Report this post
# 🚀 Introducing Granite-Docling: our New Multimodal Model for Document AI in
# Docling
# 🚀
#
# We’re excited to announce the release of Granite-Docling, a Visual Language Model designed for cost-efficient and accurate document conversion. As the follow-up to SmolDocling, Granite-Docling continues our mission of making high-quality document AI accessible to everyone. At just 258M parameters, it’s ultra-compact, highly efficient, and—importantly—permissively licensed under Apache 2.0, making it easy to adopt and build upon in research and enterprise alike.
#
# With Granite-Docling, we’ve put a lot of focus on:
#
#  🔢 Enhanced equation recognition (better math formatting), tables, OCR, inline equations, math blocks and code blocks
#  🧩 Flexible inference modes (full-page or region-based)
#  🧘 More stable decoding (avoids infinite loops)
#  🧾 Document element QA (ask questions about structure/order)
#  🌍 Experimental support for Japanese, Arabic, and Chinese
#
# Granite-Docling is now fully integrated into the Docling pipeline—ready to power the next generation of open, multimodal document understanding. Find the extensive description in our blog:
# https://lnkd.in/eBuEBRr3
# .
#
# Want to get use it?
#
# 👉 Play with our demo:
# https://lnkd.in/e-pAJZHg
# 👉 Try it out today in
# Docling
# with the cli!
#
# If you like our work, dont forget to
#
# ❤️ the Granite-Docling model on HuggingFace
# https://lnkd.in/eBsC5Kjt
# ⭐ the
# Docling
# repo
# https://lnkd.in/d4UT-6_2
# Congrats to
# Ahmed Nassar
# and
# Matteo Omenetti
# for another banger model!
#
# Special thanks to all our friends across IBM Research (cc
# David Cox
# ,
# Abraham Daniels
# ,
# Kate Soule
# , Ayhan Sebin,
# Ibrahim Ahmad Ibrahim
# ,
# Nirmit Desai
# ,
# Xuan-Hong (QuangAnh) Dang
# ,
# Yousaf Shah
# ,
# Hamid Adebayo
# ,
# Hajar Emami
# ) for all the support. I would also like to thank the
# Hugging Face
# team for all the great interactions, tools (think nanoVLM) and insights (cc
# Andrés Marafioti
# ,
# Hynek Kydlíček
# ,
# Lewis Tunstall
# ).
# 1,586
# 63 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Freddy Boulton
# Software Engineer @ 🤗
# 4d
# Report this post
# Gradio 6.0 is launching this year!
#
# We're revamping the core to give you performance improvements and unprecedented customization. Build better, faster.
#
# Check out the GitHub milestone to learn what's planned under the hood!
# https://lnkd.in/eNB9N4C4
# 151
# 2 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Daniel Vila Suero
# Building data tools @ Hugging Face 🤗
# 4d
# Report this post
# 🔥 500,000 public datasets on
# Hugging Face
# ! Perfect time to ask the community 👇
#
#
# What are we missing to help you build and share more and higher-quality datasets?
# 134
# 2 Comments
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Perplexity
# Software Development
# San Francisco, California
# Mistral AI
# Technology, Information and Internet
# Paris, France
# OpenAI
# Research Services
# San Francisco, CA
# LangChain
# Technology, Information and Internet
# Generative AI
# Technology, Information and Internet
# Google DeepMind
# Research Services
# London, London
# DeepLearning.AI
# Software Development
# Mountain View, California
# Cohere
# Software Development
# Toronto, Ontario
# NVIDIA
# Computer Hardware Manufacturing
# Santa Clara, CA
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Analyst jobs
# 694,057 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Manager jobs
# 1,880,925 open jobs
# Product Manager jobs
# 199,941 open jobs
# Director jobs
# 1,220,357 open jobs
# Python Developer jobs
# 46,642 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Data Analyst jobs
# 329,009 open jobs
# Senior Software Engineer jobs
# 78,145 open jobs
# Project Manager jobs
# 253,048 open jobs
# Researcher jobs
# 195,654 open jobs
# Associate jobs
# 1,091,945 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Specialist jobs
# 768,666 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 8 total rounds
# Last Round
# Series unknown
# Sep 1, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Scientist jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Intern jobs
# Developer jobs
# Analyst jobs
# Manager jobs
# Senior Software Engineer jobs
# Data Scientist jobs
# Researcher jobs
# Product Manager jobs
# Director jobs
# Associate jobs
# Intelligence Specialist jobs
# Data Analyst jobs
# Data Science Specialist jobs
# Python Developer jobs
# Quantitative Analyst jobs
# Project Manager jobs
# Account Executive jobs
# Specialist jobs
# Data Engineer jobs
# Designer jobs
# Quantitative Researcher jobs
# Consultant jobs
# Solutions Architect jobs
# Vice President jobs
# User Experience Designer jobs
# Head jobs
# Full Stack Engineer jobs
# Engineering Manager jobs
# Software Engineer Intern jobs
# Junior Software Engineer jobs
# Software Intern jobs
# Product Designer jobs
# Solutions Engineer jobs
# Staff Software Engineer jobs
# Program Manager jobs
# Senior Scientist jobs
# Writer jobs
# Research Intern jobs
# Senior Product Manager jobs
# Summer Intern jobs
# Account Manager jobs
# Recruiter jobs
# Lead jobs
# Research Engineer jobs
# Computer Science Intern jobs
# Platform Engineer jobs
# Junior Developer jobs
# Android Developer jobs
# User Experience Researcher jobs
# Java Software Engineer jobs
# Site Reliability Engineer jobs
# Graduate jobs
# Software Engineering Manager jobs
# Representative jobs
# Business Development Specialist jobs
# Computer Engineer jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Your California Privacy Choices
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app
#
#
#
# community discussion page
# Webpage Title:
# Hugging Face Forums - Hugging Face Community Discussion
# Webpage Contents:
# Hugging Face Forums
# Topic
# Replies
# Views
# Activity
# I have paid for pro but no update
# Beginners
# 1
# 6
# September 21, 2025
# How can I pretrain T5 model?
# 🤗Transformers
# 1
# 8
# September 21, 2025
# Chatterbox Extended
# Models
# 1
# 23
# September 20, 2025
# Custom Domain stuck on pending
# Beginners
# 1
# 21
# September 19, 2025
# Can someone help ground my delusion in AI
# Research
# 19
# 143
# September 19, 2025
# SAM2 video streaming – VRAM usage keeps increasing until OOM
# 🤗Transformers
# 3
# 28
# September 21, 2025
# Hugging Face API timeouts on all models!
# Inference Endpoints on the Hub
# 5
# 42
# September 18, 2025
# Pinokio installation is not completing
# Beginners
# 8
# 265
# September 19, 2025
# Curious About How AI Chat Models Achieve Deep Emotional Interaction
# Beginners
# 28
# 218
# September 10, 2025
# My Fine-Tuning loss is not decreasing
# Beginners
# 11
# 56
# September 19, 2025
# Unable to download a model
# Beginners
# 6
# 56
# September 20, 2025
# How to access path to audio recording in datasets 4.0?
# 🤗Datasets
# 1
# 13
# September 17, 2025
# Training from scratch: HF transformers vs pytorch lightning vs others. What is used in practice?
# 🤗Transformers
# 1
# 20
# September 17, 2025
# Have you guys noticed the new trend?
# Research
# 16
# 409
# September 16, 2025
# How Do AI Girlfriend Platforms Balance Text and Voice Training for Deep Emotional Connections?
# Beginners
# 5
# 102
# September 18, 2025
# Leaderboard is down (Gradio?)
# Spaces
# 2
# 27
# September 19, 2025
# "MandelMind: Fractal AI Consciousness Research (CC-0)"
# Research
# 59
# 272
# September 9, 2025
# HF Spaces - Gradio UI is different. Why?
# Spaces
# 10
# 68
# September 16, 2025
# CPU Dominance and an Open Challenge to the AI Community
# Show and Tell
# 21
# 39
# September 15, 2025
# Models give nonsensical answers, how do I improve them?
# Beginners
# 9
# 39
# September 18, 2025
# 403 Forbidden: Your storage patterns tripped our internal systems! Please contact us at ``website@huggingface.co`` so we can verify your account and unlock more storage for your use-case
# Models
# 4
# 75
# September 19, 2025
# 403 Forbidden Error – Cannot Use Storage
# Models
# 11
# 94
# September 19, 2025
# Customer Support Center
# Beginners
# 1
# 12
# September 18, 2025
# Cannot solve 'DynamicCache'... 'seen_tokens' error!
# Beginners
# 4
# 40
# September 16, 2025
# The best model is not being saved
# Beginners
# 3
# 16
# September 18, 2025
# Fail to push README.md updates in Hugging Face Spaces
# Spaces
# 4
# 551
# September 19, 2025
# Need help changing repository default branch
# 🤗Hub
# 1
# 265
# September 19, 2025
# [ERROR] Get error when deploy space
# Spaces
# 27
# 466
# August 14, 2025
# Working with OLMo2 , want to know if z loss is implemented
# Models
# 1
# 13
# September 18, 2025
# Model selection
# Models
# 2
# 40
# September 15, 2025
# next page →
# Home
# Categories
# Guidelines
# Terms of Service
# Privacy Policy
# Powered by
# Discourse
# , best viewed with JavaScript enabled
#
#
#
# status page
# Webpage Title:
#
# Hugging Face status
#
# Webpage Contents:
# Status
# Maintenance
# Previous incidents
# Get updates
# Get status updates
# E-mail
# RSS
# JSON
# Webhook
# Get e-mail notifications whenever Hugging Face creates, updates or resolves an incident.
# Subscribe to specific components
# Current status by service
# Huggingface Hub
# Git Hosting and Serving
# Inference Endpoints
# Inference Endpoints UI
# Inference Endpoints API
# Spaces
# Spaces Proxy
# Subscribe
# Get the RSS feed
# Get the entire status page as JSON
# Get a request to your URL whenever Hugging Face creates, updates or resolves an incident.
# We'll email you with confirmation and when there's an issue with your URL
# Subscribe to specific components
# Current status by service
# Huggingface Hub
# Git Hosting and Serving
# Inference Endpoints
# Inference Endpoints UI
# Inference Endpoints API
# Spaces
# Spaces Proxy
# Subscribe
# All services are online
# Last updated on Sep 21 at 12:17pm EDT
# Current status by service
# Operational
# Huggingface Hub
# huggingface.co
# 99.995% uptime
# Downtime
# Down for 4 minutes
# Jun 24, 2025
# Operational
# Jun 25, 2025
# Operational
# Jun 26, 2025
# Operational
# Jun 27, 2025
# Operational
# Jun 28, 2025
# Operational
# Jun 29, 2025
# Operational
# Jun 30, 2025
# Operational
# Jul 01, 2025
# Operational
# Jul 02, 2025
# Operational
# Jul 03, 2025
# Operational
# Jul 04, 2025
# Operational
# Jul 05, 2025
# Operational
# Jul 06, 2025
# Operational
# Jul 07, 2025
# Operational
# Jul 08, 2025
# Operational
# Jul 09, 2025
# Operational
# Jul 10, 2025
# Operational
# Jul 11, 2025
# Operational
# Jul 12, 2025
# Operational
# Jul 13, 2025
# Operational
# Jul 14, 2025
# Operational
# Jul 15, 2025
# Operational
# Jul 16, 2025
# Operational
# Jul 17, 2025
# Operational
# Jul 18, 2025
# Operational
# Jul 19, 2025
# Operational
# Jul 20, 2025
# Operational
# Jul 21, 2025
# Operational
# Jul 22, 2025
# Operational
# Jul 23, 2025
# Operational
# Jul 24, 2025
# Operational
# Jul 25, 2025
# Operational
# Jul 26, 2025
# Operational
# Jul 27, 2025
# Operational
# Jul 28, 2025
# Operational
# Jul 29, 2025
# Operational
# Jul 30, 2025
# Operational
# Jul 31, 2025
# Operational
# Aug 01, 2025
# Operational
# Aug 02, 2025
# Operational
# Aug 03, 2025
# Operational
# Aug 04, 2025
# Operational
# Aug 05, 2025
# Operational
# Aug 06, 2025
# Operational
# Aug 07, 2025
# Operational
# Aug 08, 2025
# Operational
# Aug 09, 2025
# Operational
# Aug 10, 2025
# Operational
# Aug 11, 2025
# Operational
# Aug 12, 2025
# Operational
# Aug 13, 2025
# Operational
# Aug 14, 2025
# Operational
# Aug 15, 2025
# Operational
# Aug 16, 2025
# Operational
# Aug 17, 2025
# Operational
# Aug 18, 2025
# Operational
# Aug 19, 2025
# Operational
# Aug 20, 2025
# Operational
# Aug 21, 2025
# Operational
# Aug 22, 2025
# Downtime
# Down for 1 minute
# Aug 23, 2025
# Operational
# Aug 24, 2025
# Operational
# Aug 25, 2025
# Operational
# Aug 26, 2025
# Operational
# Aug 27, 2025
# Operational
# Aug 28, 2025
# Operational
# Aug 29, 2025
# Operational
# Aug 30, 2025
# Operational
# Aug 31, 2025
# Operational
# Sep 01, 2025
# Operational
# Sep 02, 2025
# Operational
# Sep 03, 2025
# Operational
# Sep 04, 2025
# Operational
# Sep 05, 2025
# Operational
# Sep 06, 2025
# Operational
# Sep 07, 2025
# Operational
# Sep 08, 2025
# Operational
# Sep 09, 2025
# Operational
# Sep 10, 2025
# Operational
# Sep 11, 2025
# Operational
# Sep 12, 2025
# Operational
# Sep 13, 2025
# Operational
# Sep 14, 2025
# Operational
# Sep 15, 2025
# Operational
# Sep 16, 2025
# Operational
# Sep 17, 2025
# Operational
# Sep 18, 2025
# Operational
# Sep 19, 2025
# Operational
# Sep 20, 2025
# Operational
# Sep 21, 2025
# 30 days ago
# 60 days ago
# 90 days ago
# Today
# Git Hosting and Serving
# Hugging Face Hub, git hosting of models and datasets
# 99.988% uptime
# Downtime
# Down for 10 minutes
# Jun 24, 2025
# Operational
# Jun 25, 2025
# Downtime
# Down for 4 minutes
# Jun 26, 2025
# Operational
# Jun 27, 2025
# Operational
# Jun 28, 2025
# Operational
# Jun 29, 2025
# Operational
# Jun 30, 2025
# Operational
# Jul 01, 2025
# Operational
# Jul 02, 2025
# Operational
# Jul 03, 2025
# Operational
# Jul 04, 2025
# Operational
# Jul 05, 2025
# Operational
# Jul 06, 2025
# Operational
# Jul 07, 2025
# Operational
# Jul 08, 2025
# Operational
# Jul 09, 2025
# Operational
# Jul 10, 2025
# Operational
# Jul 11, 2025
# Operational
# Jul 12, 2025
# Operational
# Jul 13, 2025
# Operational
# Jul 14, 2025
# Operational
# Jul 15, 2025
# Operational
# Jul 16, 2025
# Operational
# Jul 17, 2025
# Operational
# Jul 18, 2025
# Operational
# Jul 19, 2025
# Operational
# Jul 20, 2025
# Operational
# Jul 21, 2025
# Operational
# Jul 22, 2025
# Operational
# Jul 23, 2025
# Operational
# Jul 24, 2025
# Operational
# Jul 25, 2025
# Operational
# Jul 26, 2025
# Operational
# Jul 27, 2025
# Operational
# Jul 28, 2025
# Operational
# Jul 29, 2025
# Operational
# Jul 30, 2025
# Operational
# Jul 31, 2025
# Operational
# Aug 01, 2025
# Operational
# Aug 02, 2025
# Operational
# Aug 03, 2025
# Operational
# Aug 04, 2025
# Operational
# Aug 05, 2025
# Operational
# Aug 06, 2025
# Operational
# Aug 07, 2025
# Operational
# Aug 08, 2025
# Operational
# Aug 09, 2025
# Operational
# Aug 10, 2025
# Operational
# Aug 11, 2025
# Operational
# Aug 12, 2025
# Operational
# Aug 13, 2025
# Operational
# Aug 14, 2025
# Operational
# Aug 15, 2025
# Operational
# Aug 16, 2025
# Operational
# Aug 17, 2025
# Operational
# Aug 18, 2025
# Operational
# Aug 19, 2025
# Operational
# Aug 20, 2025
# Operational
# Aug 21, 2025
# Operational
# Aug 22, 2025
# Operational
# Aug 23, 2025
# Operational
# Aug 24, 2025
# Operational
# Aug 25, 2025
# Operational
# Aug 26, 2025
# Operational
# Aug 27, 2025
# Operational
# Aug 28, 2025
# Operational
# Aug 29, 2025
# Operational
# Aug 30, 2025
# Operational
# Aug 31, 2025
# Operational
# Sep 01, 2025
# Operational
# Sep 02, 2025
# Operational
# Sep 03, 2025
# Operational
# Sep 04, 2025
# Operational
# Sep 05, 2025
# Operational
# Sep 06, 2025
# Operational
# Sep 07, 2025
# Operational
# Sep 08, 2025
# Operational
# Sep 09, 2025
# Operational
# Sep 10, 2025
# Operational
# Sep 11, 2025
# Operational
# Sep 12, 2025
# Operational
# Sep 13, 2025
# Operational
# Sep 14, 2025
# Operational
# Sep 15, 2025
# Operational
# Sep 16, 2025
# Operational
# Sep 17, 2025
# Operational
# Sep 18, 2025
# Operational
# Sep 19, 2025
# Operational
# Sep 20, 2025
# Operational
# Sep 21, 2025
# 30 days ago
# 60 days ago
# 90 days ago
# Today
# Inference Endpoints
# Operational
# Inference Endpoints UI
# 100.000% uptime
# Operational
# Jun 24, 2025
# Operational
# Jun 25, 2025
# Operational
# Jun 26, 2025
# Operational
# Jun 27, 2025
# Operational
# Jun 28, 2025
# Operational
# Jun 29, 2025
# Operational
# Jun 30, 2025
# Operational
# Jul 01, 2025
# Operational
# Jul 02, 2025
# Operational
# Jul 03, 2025
# Operational
# Jul 04, 2025
# Operational
# Jul 05, 2025
# Operational
# Jul 06, 2025
# Operational
# Jul 07, 2025
# Operational
# Jul 08, 2025
# Operational
# Jul 09, 2025
# Operational
# Jul 10, 2025
# Operational
# Jul 11, 2025
# Operational
# Jul 12, 2025
# Operational
# Jul 13, 2025
# Operational
# Jul 14, 2025
# Operational
# Jul 15, 2025
# Operational
# Jul 16, 2025
# Operational
# Jul 17, 2025
# Operational
# Jul 18, 2025
# Operational
# Jul 19, 2025
# Operational
# Jul 20, 2025
# Operational
# Jul 21, 2025
# Operational
# Jul 22, 2025
# Operational
# Jul 23, 2025
# Operational
# Jul 24, 2025
# Operational
# Jul 25, 2025
# Operational
# Jul 26, 2025
# Operational
# Jul 27, 2025
# Operational
# Jul 28, 2025
# Operational
# Jul 29, 2025
# Operational
# Jul 30, 2025
# Operational
# Jul 31, 2025
# Operational
# Aug 01, 2025
# Operational
# Aug 02, 2025
# Operational
# Aug 03, 2025
# Operational
# Aug 04, 2025
# Operational
# Aug 05, 2025
# Operational
# Aug 06, 2025
# Operational
# Aug 07, 2025
# Operational
# Aug 08, 2025
# Operational
# Aug 09, 2025
# Operational
# Aug 10, 2025
# Operational
# Aug 11, 2025
# Operational
# Aug 12, 2025
# Operational
# Aug 13, 2025
# Operational
# Aug 14, 2025
# Operational
# Aug 15, 2025
# Operational
# Aug 16, 2025
# Operational
# Aug 17, 2025
# Operational
# Aug 18, 2025
# Operational
# Aug 19, 2025
# Operational
# Aug 20, 2025
# Operational
# Aug 21, 2025
# Operational
# Aug 22, 2025
# Operational
# Aug 23, 2025
# Operational
# Aug 24, 2025
# Operational
# Aug 25, 2025
# Operational
# Aug 26, 2025
# Operational
# Aug 27, 2025
# Operational
# Aug 28, 2025
# Operational
# Aug 29, 2025
# Operational
# Aug 30, 2025
# Operational
# Aug 31, 2025
# Operational
# Sep 01, 2025
# Operational
# Sep 02, 2025
# Operational
# Sep 03, 2025
# Operational
# Sep 04, 2025
# Operational
# Sep 05, 2025
# Operational
# Sep 06, 2025
# Operational
# Sep 07, 2025
# Operational
# Sep 08, 2025
# Operational
# Sep 09, 2025
# Operational
# Sep 10, 2025
# Operational
# Sep 11, 2025
# Operational
# Sep 12, 2025
# Operational
# Sep 13, 2025
# Operational
# Sep 14, 2025
# Operational
# Sep 15, 2025
# Operational
# Sep 16, 2025
# Operational
# Sep 17, 2025
# Operational
# Sep 18, 2025
# Operational
# Sep 19, 2025
# Operational
# Sep 20, 2025
# Operational
# Sep 21, 2025
# 30 days ago
# 60 days ago
# 90 days ago
# Today
# Inference Endpoints API
# 100.000% uptime
# Operational
# Jun 24, 2025
# Operational
# Jun 25, 2025
# Operational
# Jun 26, 2025
# Operational
# Jun 27, 2025
# Operational
# Jun 28, 2025
# Operational
# Jun 29, 2025
# Operational
# Jun 30, 2025
# Operational
# Jul 01, 2025
# Operational
# Jul 02, 2025
# Operational
# Jul 03, 2025
# Operational
# Jul 04, 2025
# Operational
# Jul 05, 2025
# Operational
# Jul 06, 2025
# Operational
# Jul 07, 2025
# Operational
# Jul 08, 2025
# Operational
# Jul 09, 2025
# Operational
# Jul 10, 2025
# Operational
# Jul 11, 2025
# Operational
# Jul 12, 2025
# Operational
# Jul 13, 2025
# Operational
# Jul 14, 2025
# Operational
# Jul 15, 2025
# Operational
# Jul 16, 2025
# Operational
# Jul 17, 2025
# Operational
# Jul 18, 2025
# Operational
# Jul 19, 2025
# Operational
# Jul 20, 2025
# Operational
# Jul 21, 2025
# Operational
# Jul 22, 2025
# Operational
# Jul 23, 2025
# Operational
# Jul 24, 2025
# Operational
# Jul 25, 2025
# Operational
# Jul 26, 2025
# Operational
# Jul 27, 2025
# Operational
# Jul 28, 2025
# Operational
# Jul 29, 2025
# Operational
# Jul 30, 2025
# Operational
# Jul 31, 2025
# Operational
# Aug 01, 2025
# Operational
# Aug 02, 2025
# Operational
# Aug 03, 2025
# Operational
# Aug 04, 2025
# Operational
# Aug 05, 2025
# Operational
# Aug 06, 2025
# Operational
# Aug 07, 2025
# Operational
# Aug 08, 2025
# Operational
# Aug 09, 2025
# Operational
# Aug 10, 2025
# Operational
# Aug 11, 2025
# Operational
# Aug 12, 2025
# Operational
# Aug 13, 2025
# Operational
# Aug 14, 2025
# Operational
# Aug 15, 2025
# Operational
# Aug 16, 2025
# Operational
# Aug 17, 2025
# Operational
# Aug 18, 2025
# Operational
# Aug 19, 2025
# Operational
# Aug 20, 2025
# Operational
# Aug 21, 2025
# Operational
# Aug 22, 2025
# Operational
# Aug 23, 2025
# Operational
# Aug 24, 2025
# Operational
# Aug 25, 2025
# Operational
# Aug 26, 2025
# Operational
# Aug 27, 2025
# Operational
# Aug 28, 2025
# Operational
# Aug 29, 2025
# Operational
# Aug 30, 2025
# Operational
# Aug 31, 2025
# Operational
# Sep 01, 2025
# Operational
# Sep 02, 2025
# Operational
# Sep 03, 2025
# Operational
# Sep 04, 2025
# Operational
# Sep 05, 2025
# Operational
# Sep 06, 2025
# Operational
# Sep 07, 2025
# Operational
# Sep 08, 2025
# Operational
# Sep 09, 2025
# Operational
# Sep 10, 2025
# Operational
# Sep 11, 2025
# Operational
# Sep 12, 2025
# Operational
# Sep 13, 2025
# Operational
# Sep 14, 2025
# Operational
# Sep 15, 2025
# Operational
# Sep 16, 2025
# Operational
# Sep 17, 2025
# Operational
# Sep 18, 2025
# Operational
# Sep 19, 2025
# Operational
# Sep 20, 2025
# Operational
# Sep 21, 2025
# 30 days ago
# 60 days ago
# 90 days ago
# Today
# Spaces
# Operational
# Spaces Proxy
# 100.000% uptime
# Operational
# Jun 24, 2025
# Operational
# Jun 25, 2025
# Operational
# Jun 26, 2025
# Operational
# Jun 27, 2025
# Operational
# Jun 28, 2025
# Operational
# Jun 29, 2025
# Operational
# Jun 30, 2025
# Operational
# Jul 01, 2025
# Operational
# Jul 02, 2025
# Operational
# Jul 03, 2025
# Operational
# Jul 04, 2025
# Operational
# Jul 05, 2025
# Operational
# Jul 06, 2025
# Operational
# Jul 07, 2025
# Operational
# Jul 08, 2025
# Operational
# Jul 09, 2025
# Operational
# Jul 10, 2025
# Operational
# Jul 11, 2025
# Operational
# Jul 12, 2025
# Operational
# Jul 13, 2025
# Operational
# Jul 14, 2025
# Operational
# Jul 15, 2025
# Operational
# Jul 16, 2025
# Operational
# Jul 17, 2025
# Operational
# Jul 18, 2025
# Operational
# Jul 19, 2025
# Operational
# Jul 20, 2025
# Operational
# Jul 21, 2025
# Operational
# Jul 22, 2025
# Operational
# Jul 23, 2025
# Operational
# Jul 24, 2025
# Operational
# Jul 25, 2025
# Operational
# Jul 26, 2025
# Operational
# Jul 27, 2025
# Operational
# Jul 28, 2025
# Operational
# Jul 29, 2025
# Operational
# Jul 30, 2025
# Operational
# Jul 31, 2025
# Operational
# Aug 01, 2025
# Operational
# Aug 02, 2025
# Operational
# Aug 03, 2025
# Operational
# Aug 04, 2025
# Operational
# Aug 05, 2025
# Operational
# Aug 06, 2025
# Operational
# Aug 07, 2025
# Operational
# Aug 08, 2025
# Operational
# Aug 09, 2025
# Operational
# Aug 10, 2025
# Operational
# Aug 11, 2025
# Operational
# Aug 12, 2025
# Operational
# Aug 13, 2025
# Operational
# Aug 14, 2025
# Operational
# Aug 15, 2025
# Operational
# Aug 16, 2025
# Operational
# Aug 17, 2025
# Operational
# Aug 18, 2025
# Operational
# Aug 19, 2025
# Operational
# Aug 20, 2025
# Operational
# Aug 21, 2025
# Operational
# Aug 22, 2025
# Operational
# Aug 23, 2025
# Operational
# Aug 24, 2025
# Operational
# Aug 25, 2025
# Operational
# Aug 26, 2025
# Operational
# Aug 27, 2025
# Operational
# Aug 28, 2025
# Operational
# Aug 29, 2025
# Operational
# Aug 30, 2025
# Operational
# Aug 31, 2025
# Operational
# Sep 01, 2025
# Operational
# Sep 02, 2025
# Operational
# Sep 03, 2025
# Operational
# Sep 04, 2025
# Operational
# Sep 05, 2025
# Operational
# Sep 06, 2025
# Operational
# Sep 07, 2025
# Operational
# Sep 08, 2025
# Operational
# Sep 09, 2025
# Operational
# Sep 10, 2025
# Operational
# Sep 11, 2025
# Operational
# Sep 12, 2025
# Operational
# Sep 13, 2025
# Operational
# Sep 14, 2025
# Operational
# Sep 15, 2025
# Operational
# Sep 16, 2025
# Operational
# Sep 17, 2025
# Operational
# Sep 18, 2025
# Operational
# Sep 19, 2025
# Operational
# Sep 20, 2025
# Operational
# Sep 21, 2025
# 30 days ago
# 60 days ago
# 90 days ago
# Today
# Powered by
# Better Stack
#
#
#
# GitHub page
# Webpage Title:
# Hugging Face · GitHub
# Webpage Contents:
# Skip to content
# Navigation Menu
# Toggle navigation
# Sign in
# Appearance settings
# huggingface
# Platform
# GitHub Copilot
# Write better code with AI
# GitHub Spark
# New
# Build and deploy intelligent apps
# GitHub Models
# New
# Manage and compare prompts
# GitHub Advanced Security
# Find and fix vulnerabilities
# Actions
# Automate any workflow
# Codespaces
# Instant dev environments
# Issues
# Plan and track work
# Code Review
# Manage code changes
# Discussions
# Collaborate outside of code
# Code Search
# Find more, search less
# Explore
# Why GitHub
# Documentation
# GitHub Skills
# Blog
# Integrations
# GitHub Marketplace
# MCP Registry
# View all features
# Solutions
# By company size
# Enterprises
# Small and medium teams
# Startups
# Nonprofits
# By use case
# DevSecOps
# DevOps
# CI/CD
# View all use cases
# By industry
# Healthcare
# Financial services
# Manufacturing
# Government
# View all industries
# View all solutions
# Resources
# Topics
# AI
# DevOps
# Security
# Software Development
# View all
# Explore
# Learning Pathways
# Events & Webinars
# Ebooks & Whitepapers
# Customer Stories
# Partners
# Executive Insights
# Open Source
# GitHub Sponsors
# Fund open source developers
# The ReadME Project
# GitHub community articles
# Repositories
# Topics
# Trending
# Collections
# Enterprise
# Enterprise platform
# AI-powered developer platform
# Available add-ons
# GitHub Advanced Security
# Enterprise-grade security features
# Copilot for business
# Enterprise-grade AI features
# Premium Support
# Enterprise-grade 24/7 support
# Pricing
# Search or jump to...
# Search code, repositories, users, issues, pull requests...
# Search
# Clear
# Search syntax tips
# Provide feedback
# We read every piece of feedback, and take your input very seriously.
# Include my email address so I can be contacted
# Cancel
# Submit feedback
# Saved searches
# Use saved searches to filter your results more quickly
# Cancel
# Create saved search
# Sign in
# Sign up
# Appearance settings
# Resetting focus
# You signed in with another tab or window.
# Reload
# to refresh your session.
# You signed out in another tab or window.
# Reload
# to refresh your session.
# You switched accounts on another tab or window.
# Reload
# to refresh your session.
# Dismiss alert
# Hugging Face
# The AI community building the future.
# Verified
# We've verified that the organization
# huggingface
# controls the domain:
# huggingface.co
# Learn more about verified organizations
# Sponsor
# 54k
# followers
# NYC + Paris
# https://huggingface.co/
# X
# @huggingface
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# 1
# More
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# Pinned
# Loading
# transformers
# transformers
# Public
# 🤗 Transformers: the model-definition framework for state-of-the-art machine learning models in text, vision, audio, and multimodal models, for both inference and training.
# Python
# 150k
# 30.5k
# diffusers
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch.
# Python
# 30.8k
# 6.3k
# datasets
# datasets
# Public
# 🤗 The largest hub of ready-to-use datasets for AI models with fast, easy-to-use and efficient data manipulation tools
# Python
# 20.7k
# 3k
# peft
# peft
# Public
# 🤗 PEFT: State-of-the-art Parameter-Efficient Fine-Tuning.
# Python
# 19.6k
# 2k
# accelerate
# accelerate
# Public
# 🚀 A simple way to launch, train, and use PyTorch models on almost any device and distributed configuration, automatic mixed precision (including fp8), and easy-to-configure FSDP and DeepSpeed support
# Python
# 9.1k
# 1.2k
# optimum
# optimum
# Public
# 🚀 Accelerate inference and training of 🤗 Transformers, Diffusers, TIMM and Sentence Transformers with easy to use hardware optimization tools
# Python
# 3.1k
# 596
# Repositories
# Loading
# Type
# Select type
# Forks
# Archived
# Mirrors
# Templates
# Language
# Select language
# All
# C
# C#
# C++
# Cuda
# Dockerfile
# Go
# Handlebars
# HTML
# Java
# JavaScript
# Jupyter Notebook
# Kotlin
# Lua
# Makefile
# MDX
# Mustache
# Nix
# Python
# Rust
# Shell
# Smarty
# Svelte
# Swift
# TypeScript
# Sort
# Select order
# Last updated
# Name
# Stars
# Showing 10 of 347 repositories
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch.
# huggingface/diffusers’s past year of commit activity
# Python
# 30,820
# Apache-2.0
# 6,333
# 585
# (14 issues need help)
# 253
# Updated
# Sep 21, 2025
# candle
# Public
# Minimalist ML framework for Rust
# huggingface/candle’s past year of commit activity
# Rust
# 18,156
# Apache-2.0
# 1,229
# 443
# (5 issues need help)
# 131
# Updated
# Sep 21, 2025
# lerobot-dataset-visualizer
# Public
# Web application for visualizing robotics datasets in LeRobot format
# huggingface/lerobot-dataset-visualizer’s past year of commit activity
# TypeScript
# 6
# Apache-2.0
# 2
# 1
# 0
# Updated
# Sep 21, 2025
# gym-genesis
# Public
# A gym environment for GENESIS
# huggingface/gym-genesis’s past year of commit activity
# Python
# 26
# Apache-2.0
# 5
# 2
# 3
# Updated
# Sep 21, 2025
# hub-docs
# Public
# Docs of the Hugging Face Hub
# huggingface/hub-docs’s past year of commit activity
# Handlebars
# 447
# Apache-2.0
# 360
# 121
# 22
# Updated
# Sep 21, 2025
# trl
# Public
# Train transformer language models with reinforcement learning.
# huggingface/trl’s past year of commit activity
# Python
# 15,595
# Apache-2.0
# 2,202
# 487
# 78
# Updated
# Sep 20, 2025
# pytorch-image-models
# Public
# The largest collection of PyTorch image encoders / backbones. Including train, eval, inference, export scripts, and pretrained weights -- ResNet, ResNeXT, EfficientNet, NFNet, Vision Transformer (ViT), MobileNetV4, MobileNet-V3 & V2, RegNet, DPN, CSPNet, Swin Transformer, MaxViT, CoAtNet, ConvNeXt, and more
# huggingface/pytorch-image-models’s past year of commit activity
# Python
# 35,308
# Apache-2.0
# 5,015
# 53
# (4 issues need help)
# 26
# Updated
# Sep 21, 2025
# lerobot
# Public
# 🤗 LeRobot: Making AI for Robotics more accessible with end-to-end learning
# huggingface/lerobot’s past year of commit activity
# Python
# 17,445
# Apache-2.0
# 2,572
# 455
# (13 issues need help)
# 243
# Updated
# Sep 20, 2025
# transformers
# Public
# 🤗 Transformers: the model-definition framework for state-of-the-art machine learning models in text, vision, audio, and multimodal models, for both inference and training.
# huggingface/transformers’s past year of commit activity
# Python
# 150,043
# Apache-2.0
# 30,476
# 1,064
# (2 issues need help)
# 924
# Updated
# Sep 20, 2025
# doc-builder
# Public
# The package used to build the documentation of our Hugging Face repos
# huggingface/doc-builder’s past year of commit activity
# Python
# 128
# Apache-2.0
# 39
# 60
# (1 issue needs help)
# 13
# Updated
# Sep 20, 2025
# View all repositories
# People
# View all
# Sponsoring
# Top languages
# Python
# Jupyter Notebook
# TypeScript
# Rust
# MDX
# Most used topics
# pytorch
# machine-learning
# nlp
# transformers
# deep-learning
# GitHub Sponsor
# Footer
# © 2025 GitHub, Inc.
# Footer navigation
# Terms
# Privacy
# Security
# Status
# Community
# Docs
# Contact
# Manage cookies
# Do not share my personal information
# You can’t perform that action at this time.
#
#
#
# Twitter page
# Webpage Title:
# No title found
# Webpage Contents:
# JavaScript is not available.
# We’ve detected that JavaScript is disabled in this browser. Please enable JavaScript or switch to a supported browser to continue using x.com. You can see a list of supported browsers in our Help Center.
# Help Center
# Terms of Service
# Privacy Policy
# Cookie Policy
# Imprint
# Ads info
# © 2025 X Corp.
# Something went wrong, but don’t fret — let’s give it another shot.
# Try again
# Some privacy related extensions may cause issues on x.com. Please disable them and try again.

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}]}
# 'You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nCommunity\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nExplore AI Apps\nor\nBrowse 1M+ models\nTrending on\nthis week\nModels\ntencent/SRPO\nUpdated\n6 days ago\n•\n7k\n•\n862\nAlibaba-NLP/Tongyi-DeepResearch-30B-A3B\nUpdated\n4 days ago\n•\n6.26k\n•\n479\nopenbmb/VoxCPM-0.5B\nUpdated\n2 days ago\n•\n2.19k\n•\n463\nibm-granite/granite-docling-258M\nUpdated\n3 days ago\n•\n16.4k\n•\n428\ngoogle/vaultgemma-1b\nUpdated\n9 days ago\n•\n3.25k\n•\n355\nBrowse 1M+ models\nSpaces\nRunning\n14k\n14k\nDeepSite v2\n🐳\nGenerate any application with DeepSeek\nRunning\non\nZero\nMCP\n1.18k\n1.18k\nWan2.2 14B Fast\n🎥\ngenerate a video from an image with a text prompt\nRunning\n196\n196\nWan2.2 Animate\n👁\nWan2.2 Animate\nRunning\non\nZero\n241\n241\nIndexTTS 2 Demo\n🏢\nGenerate expressive speech from text with emotion control\nRunning\n137\n137\nNoWatermark\n⚡\nPowerful Watermark Removal API\nBrowse 400k+ applications\nDatasets\nHuggingFaceFW/finepdfs\nUpdated\n13 days ago\n•\n74.6k\n•\n545\nfka/awesome-chatgpt-prompts\nUpdated\nJan 6\n•\n46.7k\n•\n9.09k\nInternRobotics/OmniWorld\nUpdated\n14 minutes ago\n•\n9.93k\n•\n48\nLucasFang/FLUX-Reason-6M\nUpdated\n10 days ago\n•\n34.5k\n•\n72\nHuggingFaceM4/FineVision\nUpdated\n17 days ago\n•\n246k\n•\n336\nBrowse 250k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nTeam & Enterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nTeam\nnon-profit\n•\n792 models\n•\n4.07k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.23k models\n•\n7.93k followers\nAmazon\nEnterprise\ncompany\n•\n20 models\n•\n3.44k followers\nGoogle\nEnterprise\ncompany\n•\n1.05k models\n•\n30.1k followers\nIntel\ncompany\n•\n239 models\n•\n3.03k followers\nMicrosoft\nEnterprise\ncompany\n•\n424 models\n•\n15.5k followers\nGrammarly\nTeam\ncompany\n•\n11 models\n•\n180 followers\nWriter\nEnterprise\ncompany\n•\n30 models\n•\n348 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n150,042\nState-of-the-art AI models for PyTorch\nDiffusers\n30,820\nState-of-the-art Diffusion models in PyTorch\nSafetensors\n3,460\nSafe way to store/distribute neural network weights\nHub Python Library\n2,929\nPython client to interact with the Hugging Face Hub\nTokenizers\n10,093\nFast tokenizers optimized for research & production\nTRL\n15,595\nTrain transformers LMs with reinforcement learning\nTransformers.js\n14,578\nState-of-the-art ML running directly in your browser\nsmolagents\n22,920\nSmol library to build great agents in Python\nPEFT\n19,633\nParameter-efficient finetuning for large language models\nDatasets\n20,668\nAccess & share datasets for any ML tasks\nText G ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'blog', 'url': 'https://huggingface.co/blog'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'community forum', 'url': 'https://discuss.huggingface.co'}]}
# # Hugging Face Brochure
#
# ## Welcome to Hugging Face
# **The AI community building the future.**
# Hugging Face is the collaborative hub for the machine learning community, where individuals and organizations come together to create, share, and innovate in AI.
#
# ### What We Do
# - **Models**: Explore and collaborate on over **1 million models** ranging from natural language processing to computer vision and beyond.
# - **Datasets**: Access **250k+ datasets** to enhance and train your models.
# - **Spaces**: Develop applications in an interactive environment with over **400k applications** hosted on our platform.
#
# ### Our Community
# Hugging Face is home to an **active community** of over 60,000 AI and ML enthusiasts. Collaborate with researchers, students, and engineers from renowned organizations like:
# - **Microsoft**
# - **Google**
# - **Amazon**
# - **Meta**
# - **Intel**
#
# With continuous contributions from our users, the community thrives on mutual support and knowledge sharing.
#
# ### Company Culture
# At Hugging Face, we believe in the power of open-source collaboration. We foster an environment that emphasizes:
# - **Innovation**
# - **Inclusivity**
# - **Transparency**
#
# We encourage our team members to explore new ideas and push the boundaries of AI technology while maintaining a supportive and friendly atmosphere.
#
# ### Career Opportunities
# Join our team and become part of a mission-driven organization! We are always looking for talented individuals who want to make a difference in the AI space. Positions are available across various departments, including:
# - Data Science
# - Software Engineering
# - Community Engagement
#
# **Explore opportunities [here](https://huggingface.co/jobs)** and help shape the future of AI with us!
#
# ### Enterprise Solutions
# Hugging Face offers tailored solutions for organizations to leverage AI securely and efficiently. Our enterprise offerings include:
# - Advanced security features
# - Access controls
# - Dedicated support for smooth implementation
#
# Start building the AI solutions of tomorrow with Hugging Face!
#
# ---
#
# ### Connect with Us
# Stay updated with our latest developments and join the conversation. Follow us on:
# - [Twitter](https://twitter.com/huggingface)
# - [LinkedIn](https://www.linkedin.com/company/huggingface)
# - [Discord](https://discord.gg/huggingface)
#
# For more information, visit our website: [Hugging Face](https://huggingface.co)
#
# ---
#
# Join us in building the future of AI together!

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'docs page', 'url': 'https://huggingface.co/docs'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}]}
# # Hugging Face Company Brochure
#
# ---
#
# ## Welcome to Hugging Face
#
# ### "The AI community building the future."
#
# At Hugging Face, we are dedicated to advancing the field of Artificial Intelligence and Machine Learning. Our platform is the epicenter for collaboration, where users come together to explore, create, and innovate with hundreds of thousands of models and datasets.
#
# ---
#
# ### What We Offer
#
# - **Models**: Access to over 1 million AI models that span a variety of tasks from natural language processing to computer vision.
#
# - **Datasets**: Explore and utilize more than 250,000 datasets, making it easier to train and evaluate your models.
#
# - **Spaces**: Create and share applications within an interactive environment that supports real-time collaboration with community members.
#
# - **Enterprise Solutions**: Robust compute solutions designed for teams, featuring enterprise-grade security and dedicated support.
#
# ---
#
# ### Our Community
#
# More than 50,000 organizations trust Hugging Face for their AI needs, including industry leaders like Google, Microsoft, Amazon, and Meta. Our community is vibrant, with continuous contributions from researchers, developers, and enthusiasts who frequently collaborate on projects and share their findings.
#
# ---
#
# ### Company Culture
#
# At Hugging Face, we believe in open-source collaboration and the power of community. Our culture promotes creativity, inclusivity, and innovation. We value continuous learning and provide ample opportunities for employees to grow their skills in a supportive environment.
#
# ### Join Us
#
# As we expand, we are always on the lookout for talented individuals to join our team. Check out our careers page to find exciting job opportunities where you can contribute to shaping the future of AI.
#
# ---
#
# ### Why Choose Hugging Face?
#
# - **Collaboration**: Leverage the power of a community-driven platform to enhance your projects and ideas.
#
# - **Innovation**: Stay at the forefront of machine learning with access to cutting-edge tools and resources.
#
# - **Support**: With priority support and a wealth of documentation, you can get the assistance you need when you need it.
#
# ---
#
# Join us today and be part of our journey to build the future of artificial intelligence!
#
# *For more information, visit [Hugging Face Official Website](https://huggingface.co).*
#
# ---

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'docs page', 'url': 'https://huggingface.co/docs'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'community page', 'url': 'https://discuss.huggingface.co'}, {'type': 'status page', 'url': 'https://status.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}]}
# # Hugging Face Company Brochure
#
# ## Welcome to Hugging Face
# ### The AI Community Building the Future
#
# At Hugging Face, we are redefining the machine learning landscape. Our platform serves as a collaborative hub where AI enthusiasts, researchers, and developers come together to explore, innovate, and push the boundaries of artificial intelligence. We provide access to over one million models, datasets, and applications, making it easier than ever to harness the power of AI.
#
# ## Our Mission
# - **Community-Driven Collaboration**: We believe that the best innovations come from collective effort. Our platform encourages users to share, collaborate, and learn from one another.
# - **Open Source Excellence**: We are committed to building foundational machine learning tools in an open-source manner, fostering transparency and collaboration in the AI community.
#
# ## What We Offer
# - **Models & Datasets**: Access over 1 million AI models and 250,000 datasets for various machine learning tasks. Whether it’s text, images, videos, or audio — everything is at your fingertips.
# - **Hugging Spaces**: Create, share, and run AI applications seamlessly. With 400,000+ applications available, you can bring your ideas to life.
# - **Enterprise Solutions**: With options for teams and businesses ranging from $20/user/month, we offer enterprise-grade support, enhanced security, and dedicated resources to help organizations accelerate their AI journey.
#
# ## Our Customers
# More than **50,000 organizations** utilize Hugging Face, including tech giants like Google, Amazon, Microsoft, and AI companies like Grammarly and Meta. We take pride in being a reliable partner for enterprises looking to leverage AI technologies.
#
# | **Notable Customers** | **Models Available** | **Followers** |
# |-----------------------|----------------------|----------------|
# | Google                | 1,050                | 30.1k          |
# | Amazon                | 20                   | 3.44k          |
# | Microsoft             | 424                  | 15.5k          |
# | Grammarly             | 11                   | 180            |
#
# ## Company Culture
# At Hugging Face, we emphasize inclusion, innovation, and empowerment. Our culture reflects a strong commitment to collaboration, learning, and growth. Team members are encouraged to contribute to open-source projects, engage with the community, and pursue their passions. We believe that a diverse and inclusive environment is vital for creative solutions and fostering innovative ideas.
#
# ### Careers at Hugging Face
# We are always on the lookout for passionate individuals to join our team! Positions span a range of skills from engineering to community management. Potential candidates can expect meaningful work that contributes to the broader AI community, opportunities for professional development, and a supportive and vibrant workplace.
#
# ### Join Us!
# Whether you're a prospective customer, investor, or talent seeking your next opportunity, we invite you to discover how Hugging Face is making a difference in artificial intelligence.
#
# ✨ **Explore AI Apps, Browse Models, and Join Our Community Today!**
#
# For more information, visit [huggingface.co](https://huggingface.co).
#
# ---
# *Stay connected with us on [GitHub](https://github.com/huggingface), [Twitter](https://twitter.com/huggingface), [LinkedIn](https://linkedin.com/company/huggingface), and [Discord](https://discord.gg/huggingface).*

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>

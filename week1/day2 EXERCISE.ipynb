# %% [markdown]
# # Welcome to your first assignment!
#
# Instructions are below. Please give this a try, and look in the solutions folder if you get stuck (or feel free to ask me!)

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Just before we get to the assignment --</h2>
#             <span style="color:#f71;">I thought I'd take a second to point you at this page of useful resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # HOMEWORK EXERCISE ASSIGNMENT
#
# Upgrade the day 1 project to summarize a webpage to use an Open Source model running locally via Ollama rather than OpenAI
#
# You'll be able to use this technique for all subsequent projects if you'd prefer not to use paid APIs.
#
# **Benefits:**
# 1. No API charges - open-source
# 2. Data doesn't leave your box
#
# **Disadvantages:**
# 1. Significantly less power than Frontier Model
#
# ## Recap on installation of Ollama
#
# Simply visit [ollama.com](https://ollama.com) and install!
#
# Once complete, the ollama server should already be running locally.
# If you visit:
# [http://localhost:11434/](http://localhost:11434/)
#
# You should see the message `Ollama is running`.
#
# If not, bring up a new Terminal (Mac) or Powershell (Windows) and enter `ollama serve`
# And in another Terminal (Mac) or Powershell (Windows), enter `ollama pull llama3.2`
# Then try [http://localhost:11434/](http://localhost:11434/) again.
#
# If Ollama is slow on your machine, try using `llama3.2:1b` as an alternative. Run `ollama pull llama3.2:1b` from a Terminal or Powershell, and change the code below from `MODEL = "llama3.2"` to `MODEL = "llama3.2:1b"`

# %%
# imports

import requests
from bs4 import BeautifulSoup
from IPython.display import Markdown, display

# %%
# Constants

OLLAMA_API = "http://localhost:11434/api/chat"
HEADERS = {"Content-Type": "application/json"}
MODEL = "mistral:latest"

# %%
# Create a messages list using the same format that we used for OpenAI

messages = [
    {"role": "user", "content": "Describe some of the business applications of Generative AI"}
]

# %%
payload = {
        "model": MODEL,
        "messages": messages,
        "stream": False
    }

# %%
# Let's just make sure the model is loaded

# !ollama pull mistral:latest
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest
# pulling f5074b1221da: 100% ▕██████████████████▏ 4.4 GB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling 1ff5b64b61b9: 100% ▕██████████████████▏  799 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 1064e17101bd: 100% ▕██████████████████▏  487 B
# verifying sha256 digest
# writing manifest
# success

# %%
# If this doesn't work for any reason, try the 2 versions in the following cells
# And double check the instructions in the 'Recap on installation of Ollama' at the top of this lab
# And if none of that works - contact me!

response = requests.post(OLLAMA_API, json=payload, headers=HEADERS)
print(response.json()['message']['content'])
# Out:
#  1. Content Creation: Generative AI can be used to create engaging content such as articles, blog posts, social media updates, and even marketing copy. Tools like Articoolo, Copy.ai, and Jarvis (formerly Conversion.ai) use generative AI to produce human-like text.
#
# 2. Design and Art: In the realm of design, generative AI can create unique visual content such as logos, graphics, and even full web designs. Tools like Daz 3D, DeepArt, and Adobe Fresco use AI to generate artistic work based on user input or guidelines.
#
# 3. Music and Sound Design: Generative AI is also being used in music production to compose unique melodies, harmonies, and beats. Examples include Amper Music, Jukedeck, and AIVA, which can create original music pieces based on specific style, mood, and instrumentation.
#
# 4. Personalized Recommendations: Generative AI can analyze user data to provide personalized product recommendations, enhancing customer experience in e-commerce platforms. Tools like Edision AI help retailers generate custom product descriptions and recommendations based on user behavior and preferences.
#
# 5. Chatbots and Virtual Assistants: Generative AI powers many chatbots and virtual assistants, enabling them to engage users in human-like conversations. Tools like Google's Dialogflow, Microsoft's Bot Framework, and IBM Watson Assistant use AI to create intelligent conversational agents that can answer questions, provide information, and even perform tasks on behalf of the user.
#
# 6. Predictive Analysis: Generative AI models can analyze historical data to forecast future trends, helping businesses make informed decisions. Examples include Salesforce's Einstein Analytics, SAS Institute's AI capabilities, and Google's AutoML.
#
# 7. Drug Discovery: In the pharmaceutical industry, generative AI is being used for drug discovery by creating and testing new molecular structures to find potential treatments for various diseases. Tools like BenevolentAI and Atomwise use AI to accelerate this process.
#
# 8. Financial Analysis: Generative AI can analyze financial data to make predictions about market trends, helping investors make informed decisions. Examples include Kavout, AlphaSense, and Aidyia, which provide AI-powered financial analysis tools.

# %% [markdown]
# # Introducing the ollama package
#
# And now we'll do the same thing, but using the elegant ollama python package instead of a direct HTTP call.
#
# Under the hood, it's making the same call as above to the ollama server running at localhost:11434

# %%
import ollama

response = ollama.chat(model=MODEL, messages=messages)
print(response['message']['content'])
# Out:
#  1. Content Creation: Generative AI can be used to create various types of content such as articles, blog posts, social media updates, and even advertisement copy. This can help businesses save time and resources while ensuring consistent brand voice and messaging.
#
# 2. Personalized Marketing: Generative AI can analyze customer data to create personalized marketing messages, recommendations, and offers. This can lead to increased engagement and conversion rates as customers receive content that is tailored specifically to their interests and preferences.
#
# 3. Customer Service: Generative AI chatbots can be used to handle routine customer inquiries, freeing up human agents for more complex issues. These chatbots can learn from each interaction to provide more accurate and helpful responses over time.
#
# 4. Product Design: In the field of product design, generative AI can be used to create multiple design options based on specific parameters. This can help businesses innovate faster and more efficiently by exploring a wider range of possibilities.
#
# 5. Financial Analysis: Generative AI can analyze vast amounts of financial data to identify patterns and make predictions about future trends. This can be particularly useful for risk management, investment strategies, and financial forecasting.
#
# 6. Drug Discovery: In the pharmaceutical industry, generative AI is being used to design new molecules for potential drugs. By generating and testing millions of possible molecular structures, researchers can significantly speed up the drug discovery process.
#
# 7. Music Composition: Generative AI can also be used in music composition to create unique melodies, harmonies, and rhythms. This can help musicians and composers explore new creative possibilities and potentially discover new styles or genres.
#
# 8. Art Generation: In the world of art, generative AI can produce original pieces based on specific parameters or rules set by artists. This can lead to innovative and exciting new works that would not have been possible with traditional artistic methods.
#
# 9. Legal Document Generation: Generative AI can automate the creation of legal documents such as contracts, agreements, and forms. This can help businesses save time and money while ensuring accuracy and consistency in their legal documentation.
#
# 10. Data Augmentation: In machine learning, generative AI can be used to create synthetic data that can augment existing datasets. This can help improve the performance of machine learning models by providing them with more diverse and representative training data.

# %% [markdown]
# ## Alternative approach - using OpenAI python library to connect to Ollama

# %%
# There's actually an alternative approach that some people might prefer
# You can use the OpenAI client python library to call Ollama:

from openai import OpenAI
ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

response = ollama_via_openai.chat.completions.create(
    model=MODEL,
    messages=messages
)

print(response.choices[0].message.content)
# Out:
#  Generative AI, a subset of artificial intelligence that models and generates data, has several potential business applications. Here are a few examples:
#
# 1. Content Creation: Generative AI can be used to create new text, images, music, or even videos. For businesses, this could mean automating content creation for blogs, social media, advertisements, or product descriptions. This not only saves time but also allows for faster response times and personalization at scale.
#
# 2. Design: In the field of product design, generative AI can assist in creating new designs efficiently. It can generate multiple design options based on specific parameters, allowing designers to focus on refining and selecting the best designs instead of spending time on the initial brainstorming phase.
#
# 3. Personalization: Generative AI can help tailor experiences for individual customers. For instance, it can create personalized product recommendations or content based on users' preferences, behaviors, and interactions with the system. This increased personalization can enhance customer satisfaction and loyalty.
#
# 4. Predictive Analysis and Decision Making: Generative AI models can predict future trends based on historical data, helping businesses make more informed decisions. For example, in finance, it could identify patterns and make predictions about financial market behavior to aid in investment strategies.
#
# 5. Risk Management and Fraud Detection: Generative AI can simulate various scenarios to help businesses assess potential risks and develop risk mitigation strategies. It can also be used in fraud detection by generating models of normal user behavior and flagging unusual activities that might indicate fraudulent activities.
#
# 6. Customer Service: Chatbots powered by generative AI can respond to customer queries effectively, handle multiple conversations simultaneously, and learn from each interaction to improve over time. This continuous learning improves their efficiency in understanding customer needs and providing relevant solutions.

# %% [markdown]
# ## Are you confused about why that works?
#
# It seems strange, right? We just used OpenAI code to call Ollama?? What's going on?!
#
# Here's the scoop:
#
# The python class `OpenAI` is simply code written by OpenAI engineers that makes calls over the internet to an endpoint.
#
# When you call `openai.chat.completions.create()`, this python code just makes a web request to the following url: "https://api.openai.com/v1/chat/completions"
#
# Code like this is known as a "client library" - it's just wrapper code that runs on your machine to make web requests. The actual power of GPT is running on OpenAI's cloud behind this API, not on your computer!
#
# OpenAI was so popular, that lots of other AI providers provided identical web endpoints, so you could use the same approach.
#
# So Ollama has an endpoint running on your local box at http://localhost:11434/v1/chat/completions
# And in week 2 we'll discover that lots of other providers do this too, including Gemini and DeepSeek.
#
# And then the team at OpenAI had a great idea: they can extend their client library so you can specify a different 'base url', and use their library to call any compatible API.
#
# That's it!
#
# So when you say: `ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')`
# Then this will make the same endpoint calls, but to Ollama instead of OpenAI.

# %% [markdown]
# ## Also trying the amazing reasoning model DeepSeek
#
# Here we use the version of DeepSeek-reasoner that's been distilled to 1.5B.
# This is actually a 1.5B variant of Qwen that has been fine-tuned using synethic data generated by Deepseek R1.
#
# Other sizes of DeepSeek are [here](https://ollama.com/library/deepseek-r1) all the way up to the full 671B parameter version, which would use up 404GB of your drive and is far too large for most!

# %%
# !ollama pull deepseek-r1:1.5b

# %%
# This may take a few minutes to run! You should then see a fascinating "thinking" trace inside <think> tags, followed by some decent definitions

response = ollama_via_openai.chat.completions.create(
    model="deepseek-r1:1.5b",
    messages=[{"role": "user", "content": "Please give definitions of some core concepts behind LLMs: a neural network, attention and the transformer"}]
)

print(response.choices[0].message.content)

# %% [markdown]
# # NOW the exercise for you
#
# Take the code from day1 and incorporate it here, to build a website summarizer that uses Llama 3.2 running locally instead of OpenAI; use either of the above approaches.
